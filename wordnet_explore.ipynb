# %% [markdown]
# # Exploring WordNet subconcepts

# %%
import nltk
from nltk.corpus import wordnet as wn

# Download resources (just once)
nltk.download('wordnet')
nltk.download('omw-1.4')

def get_synsets(word):
    """Print all synsets for a given word with their definitions."""
    synsets = wn.synsets(word)
    for i, synset in enumerate(synsets):
        print(f"[{i}] {synset.name()}: {synset.definition()}")
    return synsets

def get_subclasses(synset):
    """Return the direct hyponyms (subclasses) of a given synset."""
    hyponyms = synset.hyponyms()
    if not hyponyms:
        print(f"{synset.name()} has no hyponyms.")
    else:
        for i, h in enumerate(hyponyms):
            print(f"\t[{i}] {h.name()}: {h.definition()}")
            get_subclasses(h)
        return hyponyms

word = "chair"
print(f"{'='*50}\nPrinting the sysntes for the word {word}:\n")
synsets = get_synsets(word)
loop = 1
for selected_synset in synsets:
    print(f"{'='*50}\n\tPrinting the sysntes for the word {selected_synset}:\n")
    hyponyms = get_subclasses(selected_synset)
# Out:
# ==================================================
# Printing the sysntes for the word chair:
#
# [0] chair.n.01: a seat for one person, with a support for the back
# [1] professorship.n.01: the position of professor
# [2] president.n.04: the officer who presides at the meetings of an organization
# [3] electric_chair.n.01: an instrument of execution by electrocution; resembles an ordinary seat for one person
# [4] chair.n.05: a particular seat in an orchestra
# [5] chair.v.01: act or preside as chair, as of an academic department in a university
# [6] moderate.v.01: preside over
# ==================================================
# 	Printing the sysntes for the word Synset('chair.n.01'):
#
# 	[0] armchair.n.01: chair with a support on each side for arms
# 	[0] morris_chair.n.01: an armchair with an adjustable back
# morris_chair.n.01 has no hyponyms.
# 	[1] fauteuil.n.01: an upholstered armchair
# fauteuil.n.01 has no hyponyms.
# 	[2] recliner.n.01: an armchair whose back can be lowered and foot can be raised to allow the sitter to recline in it
# recliner.n.01 has no hyponyms.
# 	[3] easy_chair.n.01: a comfortable upholstered armchair
# 	[0] wing_chair.n.01: easy chair having wings on each side of a high back
# wing_chair.n.01 has no hyponyms.
# 	[4] captain's_chair.n.01: a wooden armchair with a saddle seat and a low back that has vertical spindles
# captain's_chair.n.01 has no hyponyms.
# 	[1] chaise_longue.n.01: a long chair; for reclining
# chaise_longue.n.01 has no hyponyms.
# 	[2] fighting_chair.n.01: a fixed chair from which a saltwater angler can fight a hooked fish
# fighting_chair.n.01 has no hyponyms.
# 	[3] folding_chair.n.01: a chair that can be folded flat for storage
# 	[0] yacht_chair.n.01: a light folding armchair for outdoor use
# yacht_chair.n.01 has no hyponyms.
# 	[1] camp_chair.n.01: a light folding chair
# camp_chair.n.01 has no hyponyms.
# 	[2] deck_chair.n.01: a folding chair for use outdoors; a wooden frame supports a length of canvas
# deck_chair.n.01 has no hyponyms.
# 	[4] wheelchair.n.01: a movable chair mounted on large wheels; for invalids or those who cannot walk; frequently propelled by the occupant
# 	[0] bath_chair.n.01: a wheelchair usually pushed by an attendant, as at a spa
# bath_chair.n.01 has no hyponyms.
# 	[1] motorized_wheelchair.n.01: a wheelchair propelled by a motor
# motorized_wheelchair.n.01 has no hyponyms.
# 	[5] barber_chair.n.01: a large fixed adjustable chair in which barbers seat their customers
# barber_chair.n.01 has no hyponyms.
# 	[6] lawn_chair.n.01: chair left outside for use on a lawn or in a garden
# lawn_chair.n.01 has no hyponyms.
# 	[7] rocking_chair.n.01: a chair mounted on rockers
# 	[0] shoofly.n.02: a child's rocking chair with the seat built between two flat sides that are shaped to resemble an animal (such as a swan or duck)
# shoofly.n.02 has no hyponyms.
# 	[1] platform_rocker.n.01: rocking chair on a stationary base
# platform_rocker.n.01 has no hyponyms.
# 	[2] boston_rocker.n.01: a rocking chair that has a high spindle back and a decorative top panel
# boston_rocker.n.01 has no hyponyms.
# 	[8] eames_chair.n.01: a chair designed by Charles Eames; originally made of molded plywood; seat and back shaped to fit the human body
# eames_chair.n.01 has no hyponyms.
# 	[9] highchair.n.01: a chair for feeding a very young child; has four long legs and a footrest and a detachable tray
# highchair.n.01 has no hyponyms.
# 	[10] swivel_chair.n.01: a chair that swivels on its base
# swivel_chair.n.01 has no hyponyms.
# 	[11] tablet-armed_chair.n.01: a chair with an arm that has been widened for writing
# tablet-armed_chair.n.01 has no hyponyms.
# 	[12] straight_chair.n.01: a straight-backed chair without arms
# 	[0] windsor_chair.n.01: straight chair having a shaped seat and a back of many spindles
# windsor_chair.n.01 has no hyponyms.
# 	[13] chair_of_state.n.01: a ceremonial chair for an exalted or powerful person
# 	[0] throne.n.01: the chair of state for a monarch, bishop, etc.
# 	[0] mercy_seat.n.01: the throne of God
# mercy_seat.n.01 has no hyponyms.
# 	[1] peacock-throne.n.01: the golden throne of former kings of Delhi; stolen by the Persians in 1739 and subsequently lost; symbol of the former Shah of Iran
# peacock-throne.n.01 has no hyponyms.
# 	[2] cathedra.n.01: a throne that is the official chair of a bishop
# cathedra.n.01 has no hyponyms.
# 	[3] musnud.n.01: a seat with a cushion that is used as a throne by Indian princes
# musnud.n.01 has no hyponyms.
# 	[14] ladder-back.n.01: a chair with a ladder-back
# ladder-back.n.01 has no hyponyms.
# ==================================================
# 	Printing the sysntes for the word Synset('professorship.n.01'):
#
# professorship.n.01 has no hyponyms.
# ==================================================
# 	Printing the sysntes for the word Synset('president.n.04'):
#
# 	[0] vice_chairman.n.01: one ranking below or serving in the place of a chairman
# vice_chairman.n.01 has no hyponyms.
# 	[1] kalon_tripa.n.01: the chairman of the Kashag and essentially head of the Tibetan government-in-exile
# kalon_tripa.n.01 has no hyponyms.
# ==================================================
# 	Printing the sysntes for the word Synset('electric_chair.n.01'):
#
# electric_chair.n.01 has no hyponyms.
# ==================================================
# 	Printing the sysntes for the word Synset('chair.n.05'):
#
# chair.n.05 has no hyponyms.
# ==================================================
# 	Printing the sysntes for the word Synset('chair.v.01'):
#
# chair.v.01 has no hyponyms.
# ==================================================
# 	Printing the sysntes for the word Synset('moderate.v.01'):
#
# moderate.v.01 has no hyponyms.
# [nltk_data] Downloading package wordnet to /home/user/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/user/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
# Out:
# ==================================================
# Printing the sysntes for the word chair:
#
# [0] chair.n.01: a seat for one person, with a support for the back
# [1] professorship.n.01: the position of professor
# [2] president.n.04: the officer who presides at the meetings of an organization
# [3] electric_chair.n.01: an instrument of execution by electrocution; resembles an ordinary seat for one person
# [4] chair.n.05: a particular seat in an orchestra
# [5] chair.v.01: act or preside as chair, as of an academic department in a university
# [6] moderate.v.01: preside over
# ==================================================
# 	Printing the sysntes for the word Synset('chair.n.01'):
#
# 	[0] armchair.n.01: chair with a support on each side for arms
# 	[1] chaise_longue.n.01: a long chair; for reclining
# 	[2] fighting_chair.n.01: a fixed chair from which a saltwater angler can fight a hooked fish
# 	[3] folding_chair.n.01: a chair that can be folded flat for storage
# 	[4] wheelchair.n.01: a movable chair mounted on large wheels; for invalids or those who cannot walk; frequently propelled by the occupant
# 	[5] barber_chair.n.01: a large fixed adjustable chair in which barbers seat their customers
# 	[6] lawn_chair.n.01: chair left outside for use on a lawn or in a garden
# 	[7] rocking_chair.n.01: a chair mounted on rockers
# 	[8] eames_chair.n.01: a chair designed by Charles Eames; originally made of molded plywood; seat and back shaped to fit the human body
# 	[9] highchair.n.01: a chair for feeding a very young child; has four long legs and a footrest and a detachable tray
# 	[10] swivel_chair.n.01: a chair that swivels on its base
# 	[11] tablet-armed_chair.n.01: a chair with an arm that has been widened for writing
# 	[12] straight_chair.n.01: a straight-backed chair without arms
# 	[13] chair_of_state.n.01: a ceremonial chair for an exalted or powerful person
# 	[14] ladder-back.n.01: a chair with a ladder-back
